# %%
# To install the official MySQL Connector for Python, please use the name mysql-connector-python:
# pip install mysql-connector-python
#import mysql.connector
import datetime
import pandas as pd
import numpy as np
import urllib.request
import json

# %%
import time
import requests
from bs4 import BeautifulSoup
from functools import reduce

# %%
def load_data(file_name): 
    df = pd.read_csv(file_name)
    df.doi = df.doi.str.lower()
    return df

# %% [markdown]
# ### JASIST

# %%
jasist = load_data('JASIST_sampler - Sheet1.csv')
jasist.head()
# Out:
#                  doi                                              title  \
# 0  10.1002/asi.23606  Predicting information searchers' topic knowle...
# 1  10.1002/asi.23609  Automated arabic text classification with P‐S ...
# 2  10.1002/asi.23612  Predicting the impact of scientific concepts u...
# 3  10.1002/asi.23617  Is exploratory search different? A comparison ...
# 4  10.1002/asi.23620  Chatting through pictures? A classification of...
#
#                                               author  year_published  \
# 0                  Liu, J., Liu, C., & Belkin, N. J.            2016
# 1                            Kanan, T., & Fox, E. A.            2016
# 2  McKeown, K., Daume III, H., Chaturvedi, S., Pa...            2016
# 3  Athukorala, K., Głowacka, D., Jacucci, G., Oul...            2016
# 4  Thelwall, M., Goriunova, O., Vis, F., Faulkner...            2016
#
#     jasist_vol_Issue  gs_oa
# 0  Volume67, Issue11      0
# 1  Volume67, Issue11      1
# 2  Volume67, Issue11      1
# 3  Volume67, Issue11      1
# 4  Volume67, Issue11      1

# %%
def call_upw_api(list_of_doi):
    upw_base = 'https://api.unpaywall.org/v2/{}?email=hanlin.zhang@unc.edu'
    resp = []
    for doi in list_of_doi:
        with urllib.request.urlopen(upw_base.format(doi)) as url:
            resp.append(json.loads(url.read().decode()))
    return resp

# %%
def scihub_search(doi_list):
    res = {}
    scihub_url = 'https://sci-hub.tw/{}'
    for doi in doi_list:
        r = requests.get(scihub_url.format(doi))
        if len(r.history)>0:
            redir_url = r.history[-1].url
            res[doi] = ['?', redir_url]
        else:
            soup = BeautifulSoup(r.content)
            iframe = soup.find('iframe')
            if iframe:
                identifier = iframe.get('src')
                if ('http' or 'https') and 'pdf' in identifier:
                    res[doi] = [1, identifier.split("#")[0]]
                else:
                    res[doi] = ['?', identifier]
            else:
                res[doi] = soup
        time.sleep(2)
    return res

# %%
upw_web_res = call_upw_api(jasist.doi)
upw_web_result = {json['doi']: 0 if json['is_oa'] != True else 1 for json in upw_web_res}
upw_web_df = pd.DataFrame(list(upw_web_result.items()), columns=['doi','upw_oa'])

# %%
sh_result = scihub_search(jasist.doi)
sh_df = pd.DataFrame(list(sh_result.items()), columns=['doi','sh_res'])
sh_df['sh_oa'] = sh_df.sh_res.apply(lambda x: x[0])

# %%
tmp_frames = [jasist, upw_web_df, sh_df[['doi', 'sh_oa']]]
jasist_result = reduce(lambda  left,right: pd.merge(left,right,on='doi', how='left'), tmp_frames)

# %%
jasist_result.to_csv('jasist_result.csv')

# %%
validate(jasist, upw_web_df)
# Out:
# ******************OA Result Summary********************
#
# # of articles Google Scholar found OA: 20
# # of articles Google Scholar found NOT OA: 10
#
# # of articles Unpaywall found OA: 13
# # of articles Unpaywall found NOT OA: 17
#
# ******************End OA Result Summary****************
#                   doi  is_oa  upw_oa  check
# 0   10.1002/asi.23606      0       0      1
# 1   10.1002/asi.23609      1       1      1
# 2   10.1002/asi.23612      1       1      1
# 3   10.1002/asi.23617      1       1      1
# 4   10.1002/asi.23620      1       1      1
# 5   10.1002/asi.23621      1       1      1
# 6   10.1002/asi.23622      1       0      0
# 7   10.1002/asi.23625      1       1      1
# 8   10.1002/asi.23628      0       0      1
# 9   10.1002/asi.23629      1       1      1
# 10  10.1002/asi.23804      1       0      0
# 11  10.1002/asi.23805      1       1      1
# 12  10.1002/asi.23813      0       0      1
# 13  10.1002/asi.23814      1       1      1
# 14  10.1002/asi.23815      1       1      1
# 15  10.1002/asi.23820      0       0      1
# 16  10.1002/asi.23821      1       1      1
# 17  10.1002/asi.23834      1       0      0
# 18  10.1002/asi.23837      1       0      0
# 19  10.1002/asi.23838      0       0      1
# 20  10.1002/asi.23844      1       0      0
# 21  10.1002/asi.23850      1       1      1
# 22  10.1002/asi.23861      0       0      1
# 23  10.1002/asi.23862      1       1      1
# 24  10.1002/asi.23863      0       0      1
# 25  10.1002/asi.23872      0       0      1
# 26  10.1002/asi.23915      0       0      1
# 27  10.1002/asi.23918      0       0      1
# 28  10.1002/asi.23919      1       0      0
# 29  10.1002/asi.23925      1       0      0

# %%
# Out:
#                   doi  upw_oa
# 0   10.1002/asi.23606       0
# 1   10.1002/asi.23609       1
# 2   10.1002/asi.23612       1
# 3   10.1002/asi.23617       1
# 4   10.1002/asi.23620       1
# 5   10.1002/asi.23621       1
# 6   10.1002/asi.23622       0
# 7   10.1002/asi.23625       1
# 8   10.1002/asi.23628       0
# 9   10.1002/asi.23629       1
# 10  10.1002/asi.23804       0
# 11  10.1002/asi.23805       1
# 12  10.1002/asi.23813       0
# 13  10.1002/asi.23814       1
# 14  10.1002/asi.23815       1
# 15  10.1002/asi.23820       0
# 16  10.1002/asi.23821       1
# 17  10.1002/asi.23834       0
# 18  10.1002/asi.23837       0
# 19  10.1002/asi.23838       0
# 20  10.1002/asi.23844       0
# 21  10.1002/asi.23850       1
# 22  10.1002/asi.23861       0
# 23  10.1002/asi.23862       1
# 24  10.1002/asi.23863       0
# 25  10.1002/asi.23872       0
# 26  10.1002/asi.23915       0
# 27  10.1002/asi.23918       0
# 28  10.1002/asi.23919       0
# 29  10.1002/asi.23925       0

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-c9fe20055a71> in <module>
# ----> 1 validate(jasist, upw_result)
#
# <ipython-input-4-c2db41639f8e> in validate(vaild_df, query_df)
#      54 def validate(vaild_df, query_df):
#      55     vaild_df.is_oa = vaild_df.is_oa.astype(bool) *1
# ---> 56     query_df.upw_oa = query_df.upw_oa.astype(bool)*1
#      57     tmp = pd.merge(vaild_df[['doi', 'is_oa']], query_df, on='doi', how='left')
#      58     tmp['check'] = tmp.apply(lambda x : 0 if x['is_oa'] != x['upw_oa'] else 1, axis=1)
#
# AttributeError: 'dict' object has no attribute 'upw_oa'

# %%
 = result

# %%
jasist.doi[1]
# Out:
# '10.1002/asi.23609'

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xml:lang="en-US">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>
# 		Digital Curation Education and Training: From Digitization to Graduate Curricula to MOOCs
# 							| International Journal of Digital Curation
# 			</title>
# <link href="http://www.ijdc.net/public/journals/1/favicon_en_US.png" rel="icon"/>
# <meta content="Open Journal Systems 3.1.0.1" name="generator"/>
# <meta content="IJDC, International Journal of Digital Curation, curation, preservation, digital curation, digital preservation, DCC" name="keywords"/>
# <link href="http://www.ijdc.net/gateway/plugin/WebFeedGatewayPlugin/atom" rel="alternate" type="application/atom+xml"/>
# <link href="http://www.ijdc.net/gateway/plugin/WebFeedGatewayPlugin/rss" rel="alternate" type="application/rdf+xml"/>
# <link href="http://www.ijdc.net/gateway/plugin/WebFeedGatewayPlugin/rss2" rel="alternate" type="application/rss+xml"/>
# <link href="http://www.ijdc.net/$$$call$$$/page/page/css?name=stylesheet" rel="stylesheet" type="text/css"/><link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.css" rel="stylesheet" type="text/css"/><link href="//fonts.googleapis.com/css?family=Montserrat:400,700|Noto+Serif:400,400i,700,700i" rel="stylesheet" type="text/css"/>
# </head><body class="pkp_page_article pkp_op_view" dir="ltr">
# <div class="cmp_skip_to_content">
# <a href="#pkp_content_main">Skip to main content</a>
# <a href="#pkp_content_nav">Skip to main navigation menu</a>
# <a href="#pkp_content_footer">Skip to site footer</a>
# </div>
# <div class="pkp_structure_page">
# <header class="pkp_structure_head" id="headerNavigationContainer" role="banner">
# <div class="pkp_head_wrapper">
# <div class="pkp_site_name_wrapper">
# <div class="pkp_site_name">
# <a class="is_text" href="http://www.ijdc.net/index">International Journal of Digital Curation</a>
# </div>
# </div>
# <nav aria-label="Site Navigation" class="pkp_navigation_primary_row">
# <div class="pkp_navigation_primary_wrapper">
# <ul class="pkp_navigation_primary pkp_nav_list" id="navigationPrimary">
# <li class="">
# <a href="http://www.ijdc.net/issue/current">
# 					Current
# 				</a>
# </li>
# <li class="">
# <a href="http://www.ijdc.net/issue/archive">
# 					Archives
# 				</a>
# </li>
# <li class="">
# <a href="http://www.ijdc.net/announcement">
# 					Announcements
# 				</a>
# </li>
# <li class="">
# <a href="http://www.ijdc.net/about">
# 					About
# 				</a>
# <ul>
# <li class="">
# <a href="http://www.ijdc.net/about">
# 										About
# 									</a>
# </li>
# <li class="">
# <a href="http://www.ijdc.net/about/submissions">
# 										Submissions
# 									</a>
# </li>
# <li class="">
# <a href="http://www.ijdc.net/about/editorialTeam">
# 										Editorial Team
# 									</a>
# </li>
# <li class="">
# <a href="http://www.ijdc.net/about/contact">
# 										Contact
# 									</a>
# </li>
# </ul>
# </li>
# </ul>
# <form action="http://www.ijdc.net/search/search" class="pkp_search" method="post" role="search">
# <input name="csrfToken" type="hidden" value="0e6178c03e9aab69c7a8a6a56daca2a1"/>
# <input aria-label="Search Query" name="query" type="text" value=""/>
# <button type="submit">
# 			Search
# 		</button>
# <div aria-hidden="true" class="search_controls">
# <a aria-hidden="true" class="headerSearchPrompt search_prompt" href="http://www.ijdc.net/search/search">
# 				Search
# 			</a>
# <a aria-hidden="true" class="search_cancel headerSearchCancel" href="#"></a>
# <span aria-hidden="true" class="search_loading"></span>
# </div>
# </form>
# </div>
# </nav>
# <nav aria-label="User Navigation" class="pkp_navigation_user_wrapper" id="navigationUserWrapper">
# <ul class="pkp_navigation_user pkp_nav_list" id="navigationUser">
# <li class="profile">
# <a href="http://www.ijdc.net/user/register">
# 					Register
# 				</a>
# </li>
# <li class="profile">
# <a href="http://www.ijdc.net/login">
# 					Login
# 				</a>
# </li>
# </ul>
# </nav>
# </div><!-- .pkp_head_wrapper -->
# </header><!-- .pkp_structure_head -->
# <div class="pkp_structure_content has_sidebar">
# <div class="pkp_structure_main" id="pkp_content_main" role="main">
# <div class="page page_article">
# <nav aria-label="You are here:" class="cmp_breadcrumbs" role="navigation">
# <ol>
# <li>
# <a href="http://www.ijdc.net/index">
# 				Home
# 			</a>
# <span class="separator">/</span>
# </li>
# <li>
# <a href="http://www.ijdc.net/issue/archive">
# 				Archives
# 			</a>
# <span class="separator">/</span>
# </li>
# <li>
# <a href="http://www.ijdc.net/issue/view/20">
# 				Vol 10 No 1 (2015)
# 			</a>
# <span class="separator">/</span>
# </li>
# <li class="current">
# 									Articles
# 						</li>
# </ol>
# </nav>
# <article class="obj_article_details">
# <h1 class="page_title">
# 		Digital Curation Education and Training: From Digitization to Graduate Curricula to MOOCs
# 	</h1>
# <div class="row">
# <div class="main_entry">
# <ul class="item authors">
# <li>
# <span class="name">
# 								Helen R. Tibbo
# 							</span>
# </li>
# </ul>
# <div class="item doi">
# <span class="label">
# 														DOI:
# 						</span>
# <span class="value">
# <a href="https://doi.org/10.2218/ijdc.v10i1.352">
# 								https://doi.org/10.2218/ijdc.v10i1.352
# 							</a>
# </span>
# </div>
# <div class="item abstract">
# <h3 class="label">Abstract</h3>
# <p>This paper traces the development of digital and data curation curricula. Due to the brief length of this paper, the focus is on North American initiatives and primarily on continuing education programs. It explores the strengths and weaknesses of professional workshops and the creation of graduate-level courses, certificates, degrees and MOOCs, as well as the role of funding agencies in this process. It concludes with an analysis of what is missing and what is needed to create the workforce required to steward digital assets in the foreseeable future.</p>
# </div>
# </div><!-- .main_entry -->
# <div class="entry_details">
# <div class="item galleys">
# <ul class="value galleys_links">
# <li>
# <a class="obj_galley_link pdf" href="http://www.ijdc.net/article/view/10.1.144/387">
#
#
# 	PDF
#
# 	</a> </li>
# </ul>
# </div>
# <div class="item published">
# <div class="label">
# 						Published
# 					</div>
# <div class="value">
# 						18-Mar-2015
# 					</div>
# </div>
# <div class="item issue">
# <div class="sub_item">
# <div class="label">
# 						Issue
# 					</div>
# <div class="value">
# <a class="title" href="http://www.ijdc.net/issue/view/20">
# 							Vol 10 No 1 (2015)
# 						</a>
# </div>
# </div>
# <div class="sub_item">
# <div class="label">
# 							Section
# 						</div>
# <div class="value">
# 							Articles
# 						</div>
# </div>
# </div>
# <div class="item copyright">
# <p>Copyright for papers and articles published in this journal is retained by the authors, with first publication rights granted to the University of Edinburgh. It is a condition of publication that authors license their paper or article under a <a href="http://creativecommons.org/licenses/by/4.0/" rel="license">Creative Commons Attribution Licence</a>.<br/><br/><a href="http://creativecommons.org/licenses/by/4.0/" rel="license"><img alt="Creative Commons License" src="http://i.creativecommons.org/l/by/2.5/scotland/88x31.png" style="border-width: 0;"/></a></p>
# </div>
# </div><!-- .entry_details -->
# </div><!-- .row -->
# </article>
# </div><!-- .page -->
# </div><!-- pkp_structure_main -->
# <div aria-label="Sidebar" class="pkp_structure_sidebar left" role="complementary">
# <div class="pkp_block block_developed_by">
# <div class="content">
# <a href="http://pkp.sfu.ca/ojs/">
# 			Open Journal Systems
# 		</a>
# </div>
# </div><div class="pkp_block block_information">
# <span class="title">Information</span>
# <div class="content">
# <ul>
# <li>
# <a href="http://www.ijdc.net/information/readers">
# 						For Readers
# 					</a>
# </li>
# <li>
# <a href="http://www.ijdc.net/information/authors">
# 						For Authors
# 					</a>
# </li>
# <li>
# <a href="http://www.ijdc.net/information/librarians">
# 						For Librarians
# 					</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="pkp_block block_web_feed">
# <span class="title">Current Issue</span>
# <div class="content">
# <ul>
# <li>
# <a href="http://www.ijdc.net/gateway/plugin/WebFeedGatewayPlugin/atom">
# <img alt="Atom logo" src="http://www.ijdc.net/lib/pkp/templates/images/atom.svg"/>
# </a>
# </li>
# <li>
# <a href="http://www.ijdc.net/gateway/plugin/WebFeedGatewayPlugin/rss2">
# <img alt="RSS2 logo" src="http://www.ijdc.net/lib/pkp/templates/images/rss20_logo.svg"/>
# </a>
# </li>
# <li>
# <a href="http://www.ijdc.net/gateway/plugin/WebFeedGatewayPlugin/rss">
# <img alt="RSS1 logo" src="http://www.ijdc.net/lib/pkp/templates/images/rss10_logo.svg"/>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div><!-- pkp_sidebar.left -->
# </div><!-- pkp_structure_content -->
# <div class="pkp_structure_footer_wrapper" id="pkp_content_footer" role="contentinfo">
# <div class="pkp_structure_footer">
# <div class="pkp_brand_footer" role="complementary">
# <a href="http://www.ijdc.net/about/aboutThisPublishingSystem">
# <img alt="About this Publishing System" src="http://www.ijdc.net/templates/images/ojs_brand.png"/>
# </a>
# </div>
# </div>
# </div><!-- pkp_structure_footer_wrapper -->
# </div><!-- pkp_structure_page -->
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js" type="text/javascript"></script><script src="//ajax.googleapis.com/ajax/libs/jqueryui/1.11.0/jquery-ui.min.js" type="text/javascript"></script><script src="http://www.ijdc.net/lib/pkp/js/lib/jquery/plugins/jquery.tag-it.js" type="text/javascript"></script><script src="http://www.ijdc.net/plugins/themes/default/js/lib/popper/popper.js" type="text/javascript"></script><script src="http://www.ijdc.net/plugins/themes/default/js/lib/bootstrap/util.js" type="text/javascript"></script><script src="http://www.ijdc.net/plugins/themes/default/js/lib/bootstrap/dropdown.js" type="text/javascript"></script><script src="http://www.ijdc.net/plugins/themes/default/js/main.js" type="text/javascript"></script><script type="text/javascript">
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
# ga('create', 'UA-21721333-2', 'auto');
# ga('send', 'pageview');
# </script>
# </body>
# </html>

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xml:lang="en-US">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>
# 		Digital Curation Education and Training: From Digitization to Graduate Curricula to MOOCs
# 							| International Journal of Digital Curation
# 			</title>
# <link href="http://www.ijdc.net/public/journals/1/favicon_en_US.png" rel="icon"/>
# <meta content="Open Journal Systems 3.1.0.1" name="generator"/>
# <meta content="IJDC, International Journal of Digital Curation, curation, preservation, digital curation, digital preservation, DCC" name="keywords"/>
# <link href="http://www.ijdc.net/gateway/plugin/WebFeedGatewayPlugin/atom" rel="alternate" type="application/atom+xml"/>
# <link href="http://www.ijdc.net/gateway/plugin/WebFeedGatewayPlugin/rss" rel="alternate" type="application/rdf+xml"/>
# <link href="http://www.ijdc.net/gateway/plugin/WebFeedGatewayPlugin/rss2" rel="alternate" type="application/rss+xml"/>
# <link href="http://www.ijdc.net/$$$call$$$/page/page/css?name=stylesheet" rel="stylesheet" type="text/css"/><link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.css" rel="stylesheet" type="text/css"/><link href="//fonts.googleapis.com/css?family=Montserrat:400,700|Noto+Serif:400,400i,700,700i" rel="stylesheet" type="text/css"/>
# </head><body class="pkp_page_article pkp_op_view" dir="ltr">
# <div class="cmp_skip_to_content">
# <a href="#pkp_content_main">Skip to main content</a>
# <a href="#pkp_content_nav">Skip to main navigation menu</a>
# <a href="#pkp_content_footer">Skip to site footer</a>
# </div>
# <div class="pkp_structure_page">
# <header class="pkp_structure_head" id="headerNavigationContainer" role="banner">
# <div class="pkp_head_wrapper">
# <div class="pkp_site_name_wrapper">
# <div class="pkp_site_name">
# <a class="is_text" href="http://www.ijdc.net/index">International Journal of Digital Curation</a>
# </div>
# </div>
# <nav aria-label="Site Navigation" class="pkp_navigation_primary_row">
# <div class="pkp_navigation_primary_wrapper">
# <ul class="pkp_navigation_primary pkp_nav_list" id="navigationPrimary">
# <li class="">
# <a href="http://www.ijdc.net/issue/current">
# 					Current
# 				</a>
# </li>
# <li class="">
# <a href="http://www.ijdc.net/issue/archive">
# 					Archives
# 				</a>
# </li>
# <li class="">
# <a href="http://www.ijdc.net/announcement">
# 					Announcements
# 				</a>
# </li>
# <li class="">
# <a href="http://www.ijdc.net/about">
# 					About
# 				</a>
# <ul>
# <li class="">
# <a href="http://www.ijdc.net/about">
# 										About
# 									</a>
# </li>
# <li class="">
# <a href="http://www.ijdc.net/about/submissions">
# 										Submissions
# 									</a>
# </li>
# <li class="">
# <a href="http://www.ijdc.net/about/editorialTeam">
# 										Editorial Team
# 									</a>
# </li>
# <li class="">
# <a href="http://www.ijdc.net/about/contact">
# 										Contact
# 									</a>
# </li>
# </ul>
# </li>
# </ul>
# <form action="http://www.ijdc.net/search/search" class="pkp_search" method="post" role="search">
# <input name="csrfToken" type="hidden" value="003e9b50855cc52f1651bfa9391e90d3"/>
# <input aria-label="Search Query" name="query" type="text" value=""/>
# <button type="submit">
# 			Search
# 		</button>
# <div aria-hidden="true" class="search_controls">
# <a aria-hidden="true" class="headerSearchPrompt search_prompt" href="http://www.ijdc.net/search/search">
# 				Search
# 			</a>
# <a aria-hidden="true" class="search_cancel headerSearchCancel" href="#"></a>
# <span aria-hidden="true" class="search_loading"></span>
# </div>
# </form>
# </div>
# </nav>
# <nav aria-label="User Navigation" class="pkp_navigation_user_wrapper" id="navigationUserWrapper">
# <ul class="pkp_navigation_user pkp_nav_list" id="navigationUser">
# <li class="profile">
# <a href="http://www.ijdc.net/user/register">
# 					Register
# 				</a>
# </li>
# <li class="profile">
# <a href="http://www.ijdc.net/login">
# 					Login
# 				</a>
# </li>
# </ul>
# </nav>
# </div><!-- .pkp_head_wrapper -->
# </header><!-- .pkp_structure_head -->
# <div class="pkp_structure_content has_sidebar">
# <div class="pkp_structure_main" id="pkp_content_main" role="main">
# <div class="page page_article">
# <nav aria-label="You are here:" class="cmp_breadcrumbs" role="navigation">
# <ol>
# <li>
# <a href="http://www.ijdc.net/index">
# 				Home
# 			</a>
# <span class="separator">/</span>
# </li>
# <li>
# <a href="http://www.ijdc.net/issue/archive">
# 				Archives
# 			</a>
# <span class="separator">/</span>
# </li>
# <li>
# <a href="http://www.ijdc.net/issue/view/20">
# 				Vol 10 No 1 (2015)
# 			</a>
# <span class="separator">/</span>
# </li>
# <li class="current">
# 									Articles
# 						</li>
# </ol>
# </nav>
# <article class="obj_article_details">
# <h1 class="page_title">
# 		Digital Curation Education and Training: From Digitization to Graduate Curricula to MOOCs
# 	</h1>
# <div class="row">
# <div class="main_entry">
# <ul class="item authors">
# <li>
# <span class="name">
# 								Helen R. Tibbo
# 							</span>
# </li>
# </ul>
# <div class="item doi">
# <span class="label">
# 														DOI:
# 						</span>
# <span class="value">
# <a href="https://doi.org/10.2218/ijdc.v10i1.352">
# 								https://doi.org/10.2218/ijdc.v10i1.352
# 							</a>
# </span>
# </div>
# <div class="item abstract">
# <h3 class="label">Abstract</h3>
# <p>This paper traces the development of digital and data curation curricula. Due to the brief length of this paper, the focus is on North American initiatives and primarily on continuing education programs. It explores the strengths and weaknesses of professional workshops and the creation of graduate-level courses, certificates, degrees and MOOCs, as well as the role of funding agencies in this process. It concludes with an analysis of what is missing and what is needed to create the workforce required to steward digital assets in the foreseeable future.</p>
# </div>
# </div><!-- .main_entry -->
# <div class="entry_details">
# <div class="item galleys">
# <ul class="value galleys_links">
# <li>
# <a class="obj_galley_link pdf" href="http://www.ijdc.net/article/view/10.1.144/387">
#
#
# 	PDF
#
# 	</a> </li>
# </ul>
# </div>
# <div class="item published">
# <div class="label">
# 						Published
# 					</div>
# <div class="value">
# 						18-Mar-2015
# 					</div>
# </div>
# <div class="item issue">
# <div class="sub_item">
# <div class="label">
# 						Issue
# 					</div>
# <div class="value">
# <a class="title" href="http://www.ijdc.net/issue/view/20">
# 							Vol 10 No 1 (2015)
# 						</a>
# </div>
# </div>
# <div class="sub_item">
# <div class="label">
# 							Section
# 						</div>
# <div class="value">
# 							Articles
# 						</div>
# </div>
# </div>
# <div class="item copyright">
# <p>Copyright for papers and articles published in this journal is retained by the authors, with first publication rights granted to the University of Edinburgh. It is a condition of publication that authors license their paper or article under a <a href="http://creativecommons.org/licenses/by/4.0/" rel="license">Creative Commons Attribution Licence</a>.<br/><br/><a href="http://creativecommons.org/licenses/by/4.0/" rel="license"><img alt="Creative Commons License" src="http://i.creativecommons.org/l/by/2.5/scotland/88x31.png" style="border-width: 0;"/></a></p>
# </div>
# </div><!-- .entry_details -->
# </div><!-- .row -->
# </article>
# </div><!-- .page -->
# </div><!-- pkp_structure_main -->
# <div aria-label="Sidebar" class="pkp_structure_sidebar left" role="complementary">
# <div class="pkp_block block_developed_by">
# <div class="content">
# <a href="http://pkp.sfu.ca/ojs/">
# 			Open Journal Systems
# 		</a>
# </div>
# </div><div class="pkp_block block_information">
# <span class="title">Information</span>
# <div class="content">
# <ul>
# <li>
# <a href="http://www.ijdc.net/information/readers">
# 						For Readers
# 					</a>
# </li>
# <li>
# <a href="http://www.ijdc.net/information/authors">
# 						For Authors
# 					</a>
# </li>
# <li>
# <a href="http://www.ijdc.net/information/librarians">
# 						For Librarians
# 					</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="pkp_block block_web_feed">
# <span class="title">Current Issue</span>
# <div class="content">
# <ul>
# <li>
# <a href="http://www.ijdc.net/gateway/plugin/WebFeedGatewayPlugin/atom">
# <img alt="Atom logo" src="http://www.ijdc.net/lib/pkp/templates/images/atom.svg"/>
# </a>
# </li>
# <li>
# <a href="http://www.ijdc.net/gateway/plugin/WebFeedGatewayPlugin/rss2">
# <img alt="RSS2 logo" src="http://www.ijdc.net/lib/pkp/templates/images/rss20_logo.svg"/>
# </a>
# </li>
# <li>
# <a href="http://www.ijdc.net/gateway/plugin/WebFeedGatewayPlugin/rss">
# <img alt="RSS1 logo" src="http://www.ijdc.net/lib/pkp/templates/images/rss10_logo.svg"/>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div><!-- pkp_sidebar.left -->
# </div><!-- pkp_structure_content -->
# <div class="pkp_structure_footer_wrapper" id="pkp_content_footer" role="contentinfo">
# <div class="pkp_structure_footer">
# <div class="pkp_brand_footer" role="complementary">
# <a href="http://www.ijdc.net/about/aboutThisPublishingSystem">
# <img alt="About this Publishing System" src="http://www.ijdc.net/templates/images/ojs_brand.png"/>
# </a>
# </div>
# </div>
# </div><!-- pkp_structure_footer_wrapper -->
# </div><!-- pkp_structure_page -->
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js" type="text/javascript"></script><script src="//ajax.googleapis.com/ajax/libs/jqueryui/1.11.0/jquery-ui.min.js" type="text/javascript"></script><script src="http://www.ijdc.net/lib/pkp/js/lib/jquery/plugins/jquery.tag-it.js" type="text/javascript"></script><script src="http://www.ijdc.net/plugins/themes/default/js/lib/popper/popper.js" type="text/javascript"></script><script src="http://www.ijdc.net/plugins/themes/default/js/lib/bootstrap/util.js" type="text/javascript"></script><script src="http://www.ijdc.net/plugins/themes/default/js/lib/bootstrap/dropdown.js" type="text/javascript"></script><script src="http://www.ijdc.net/plugins/themes/default/js/main.js" type="text/javascript"></script><script type="text/javascript">
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
# ga('create', 'UA-21721333-2', 'auto');
# ga('send', 'pageview');
# </script>
# </body>
# </html>

# %%
iframe

# %%
identifier
# Out:
# 'https://twin.sci-hub.tw/5761/edc084961ee67612f76456a6e25c03b3/liu2015.pdf#view=FitH'

# %%
response

# %%
upw_db_result = search_db('saa', jasist)
# Out:
# Executing query:
# SELECT doi, is_oa FROM tmp WHERE doi IN ('10.1002/asi.23606','10.1002/asi.23609','10.1002/asi.23612','10.1002/asi.23617','10.1002/asi.23620','10.1002/asi.23621','10.1002/asi.23622','10.1002/asi.23625','10.1002/asi.23628','10.1002/asi.23629','10.1002/asi.23804','10.1002/asi.23805','10.1002/asi.23813','10.1002/asi.23814','10.1002/asi.23815','10.1002/asi.23820','10.1002/asi.23821','10.1002/asi.23834','10.1002/asi.23837','10.1002/asi.23838','10.1002/asi.23844','10.1002/asi.23850','10.1002/asi.23861','10.1002/asi.23862','10.1002/asi.23863','10.1002/asi.23872','10.1002/asi.23915','10.1002/asi.23918','10.1002/asi.23919','10.1002/asi.23925')
#
# # of article found in upw db:27

# %%
upw_add_result = search_missing(jasist, upw_db_result)
upw_df = pd.DataFrame(list({**upw_db_result, **upw_add_result}.items()), columns=['doi','upw_oa'])
# Out:
# Missing doi:
# ['10.1002/asi.23813', '10.1002/asi.23629', '10.1002/asi.23621']
# # total missing doi: 3
# # valid missing doi: 3
# # of brocken missing doi: 0

# %%
jasist_result = validate(jasist, upw_df)
jasist_result.head()
# Out:
# ******************OA Result Summary********************
#
# # of articles Google Scholar found OA: 20
# # of articles Google Scholar found NOT OA: 10
#
# # of articles Unpaywall found OA: 16
# # of articles Unpaywall found NOT OA: 14
#
# ******************End OA Result Summary****************
#                  doi  is_oa  upw_oa  check
# 0  10.1002/asi.23606      0       0      1
# 1  10.1002/asi.23609      1       1      1
# 2  10.1002/asi.23612      1       0      0
# 3  10.1002/asi.23617      1       1      1
# 4  10.1002/asi.23620      1       1      1

# %%
jasist_diff = evaluation(jasist_result)
# Out:
# Within those 16 articles Unpaywall found OA:
# 14 is (are) acutally OA.
#
# Within those 14 articles Unpaywall NOT found OA:
# 8 is (are) acutally NOT OA.
#
# Precision = 14 / 16 = 87.5%
# Racall = 14 / 20 = 70.0%

# %%
jasist_diff
# Out:
#                   doi  is_oa  upw_oa  check
# 2   10.1002/asi.23612      1       0      0
# 6   10.1002/asi.23622      1       0      0
# 10  10.1002/asi.23804      1       0      0
# 17  10.1002/asi.23834      1       0      0
# 18  10.1002/asi.23837      1       0      0
# 20  10.1002/asi.23844      1       0      0
# 26  10.1002/asi.23915      0       1      0
# 27  10.1002/asi.23918      0       1      0

# %% [markdown]
# ### Han's 50 article sampler

# %%
oa_sampler = load_data('oa_atricle_sampler.csv')
oa_sampler.head()
# Out:
#                                    doi  \
# 0               10.3842/sigma.2012.016
# 1        10.1016/j.physrep.2012.01.001
# 2  10.1146/annurev-astro-081811-125615
# 3       10.1016/j.physletb.2008.07.018
# 4              10.1126/science.1202043
#
#                                                title  \
# 0           Introduction to loop quantum cosmology\n
# 1                     Modified gravity and cosmology
# 2                      Cosmic star-formation history
# 3                       Review of Particle Physics\n
# 4  Improved Learning in a Large-Enrollment Physic...
#
#                                               author  year_published  \
# 0    Banerjee, K., Calcagni, G., & Martín-Benito, M.            2010
# 1  Clifton, T., Ferreira, P. G., Padilla, A., & S...            2012
# 2                         Madau, P., & Dickinson, M.            2014
# 3  C. Amsler, M. Doser, M. Antonelli, D. M. Asner...            2008
# 4         Deslauriers, L., Schelew, E., & Wieman, C.            2011
#
#   field of study  is_oa
# 0        Physics      1
# 1        Physics      1
# 2        Physics      1
# 3        Physics      1
# 4        Physics      1

# %%
oa_result = scihub_search(oa_sampler.doi)

# %%
oa_result
# Out:
# {'10.3842/sigma.2012.016': [1,
#   'https://dabamirror.sci-hub.tw/4115/47c785afe206020941a471d4453ae5c7/banerjee2012.pdf'],
#  '10.1016/j.physrep.2012.01.001': [1,
#   'https://zero.sci-hub.tw/1355/ab573c3f79b0659f267c56fa3dffedfc/clifton2012.pdf'],
#  '10.1146/annurev-astro-081811-125615': [1,
#   'https://zero.sci-hub.tw/2710/2d03acc726350371c156b24b109dcf26/madau2014.pdf'],
#  '10.1016/j.physletb.2008.07.018': [1,
#   'https://moscow.sci-hub.tw/379/440690fdc4b707223b31740c41226c0e/amsler2008.pdf'],
#  '10.1126/science.1202043': [1,
#   'https://dacemirror.sci-hub.tw/journal-article/232d114b7f83fd2c9289fa5be4422b1d/boly2011.pdf'],
#  '10.1140/epjc/s10052-016-4099-4': [1,
#   'https://moscow.sci-hub.tw/5330/7020d8c50be1400eaee4c7e829230893/baldi2016.pdf'],
#  '10.1016/j.aop.2005.04.002': [1,
#   'https://dacemirror.sci-hub.tw/journal-article/f0d6890795e243cfd183f2bb5e955220/pospelov2005.pdf'],
#  '10.1103/physrevlett.94.111601': [1,
#   'https://moscow.sci-hub.tw/1533/6b8d3b2ce7150c545c8743ec01fa5a92/kovtun2005.pdf'],
#  '10.1143/ptps.183.1': [1,
#   'https://zero.sci-hub.tw/1831/1d9816654d3502706a702544c1d0a0b9/ishimori2010.pdf'],
#  '10.1143/ptp.113.843': [1,
#   'https://moscow.sci-hub.tw/2690/1a9c920e22dc8bad967d7390c7268c58/sakai2005.pdf'],
#  '10.1371/journal.pone.0064841': [1,
#   'https://twin.sci-hub.tw/6939/053d9f16bb168348c3d55dcd9380bc52/thelwall2013.pdf'],
#  '10.1108/jd-03-2016-0030': [1,
#   'https://twin.sci-hub.tw/6245/5ad89be51b2d34978caf92aee548ee9d/feinberg2017.pdf'],
#  '10.1007/s10900-018-0547-4': [1,
#   'https://twin.sci-hub.tw/7160/f69992709a394f7b8826d363eac5cff3/philbin2018.pdf'],
#  '10.1016/j.ijinfomgt.2018.07.004': [1,
#   'https://twin.sci-hub.tw/7110/d04e37ee984315a65582b3ddbc9ecc80/sutherland2018.pdf'],
#  '10.1016/j.lisr.2017.03.001': [1,
#   'https://twin.sci-hub.tw/6340/853f827ea436dde721f64555165a7597/gibson2017.pdf'],
#  '10.1016/j.lisr.2017.03.005': [1,
#   'https://twin.sci-hub.tw/6338/c9f968288a63456e97e4b38195430d51/shah2017.pdf'],
#  '10.1002/asi.23124': [1,
#   'https://dacemirror.sci-hub.tw/journal-article/05d0ed562b3e4e6c94403076497fb6ee/hemminger2014.pdf'],
#  '10.1145/2998181.2998204': [1,
#   'https://twin.sci-hub.tw/6563/2b2c2e8321a15283295edf8be791c33a/feinberg2017.pdf'],
#  '10.1108/jd-06-2017-0095': [1,
#   'https://twin.sci-hub.tw/6852/c2f80d64148fb724b554725d9748bc17/maron2018.pdf'],
#  '10.1080/10447318.2017.1365459': [1,
#   'https://dacemirror.sci-hub.tw/journal-article/17e81e161673afce870c259d3a7ce68e/mosaly2017.pdf'],
#  '10.1177/1464884905056815': [1,
#   '//sci-hub.tw/downloads/2019-01-24//a2/deuze2005.pdf'],
#  '10.1177/1464884903004001484': [1,
#   'https://dacemirror.sci-hub.tw/journal-article/d7a5719c636e3dc641a81f51660185b4/deburgh2003.pdf'],
#  '10.1080/1461670x.2011.571825': [1,
#   'https://moscow.sci-hub.tw/2265/58af4c3f1e855798efc2261df865a9a4/lasorsa2012.pdf'],
#  '10.1080/17512780802281065': [1,
#   'https://zero.sci-hub.tw/2290/90a765626802c81354b90edd01b8cfbd/domingo2008.pdf'],
#  '10.1080/17512786.2012.667269': [1,
#   'https://zero.sci-hub.tw/3562/08059afdae79f28169ab0fbf6e328bc7/hermida2012.pdf'],
#  '10.1207/s15506878jobem4604_3': [1,
#   'https://moscow.sci-hub.tw/3904/19fde9ddb42dc38ffa5b0a401b755c47/cohen2002.pdf'],
#  '10.1177/1461444809341393': [1,
#   'https://zero.sci-hub.tw/3986/4cccc9270029e4d0d49425fe9afcbe4d/goode2009.pdf'],
#  '10.1177/0016549205057564': [1,
#   'https://cyber.sci-hub.tw/MTAuMTE3Ny8wMDE2NTQ5MjA1MDU3NTY0/josephi2005.pdf'],
#  '10.1080/14616700500533643': [1,
#   'https://moscow.sci-hub.tw/1831/cbb30894f28eb1eb56f5b607933f863a/golan2006.pdf'],
#  '10.1080/14616700118394': [1,
#   'https://zero.sci-hub.tw/3497/aa166ae040f67cc249c466f50e74bfed/reese2001.pdf'],
#  '10.3390/ijerph14091002': [1,
#   'https://dacemirror.sci-hub.tw/journal-article/c3f095a42cbb82fcc65285eda817eeb9/zhang2017.pdf'],
#  '10.1097/phh.0000000000000347': [1,
#   'https://twin.sci-hub.tw/6508/a5f1631b738445b3bcc4128a43b8b889/hoss2016.pdf'],
#  '10.11604/pamj.supp.2017.27.1.12570': ['?',
#   'https://sci-hub.tw/https://dnspod.qcloud.com/static/webblock.html?d=www.panafrican-med-journal.com'],
#  '10.1093/pubmed/fdw130': [1,
#   'https://twin.sci-hub.tw/6509/257cdbc2380da578f88db556258ee73e/oup-accepted-manuscript-2016.pdf'],
#  '10.24095/hpcdp.38.7/8.02': ['?',
#   'https://sci-hub.tw/https://www.canada.ca/en/public-health/services/reports-publications/health-promotion-chronic-disease-prevention-canada-research-policy-practice/vol-38-no-7-8-2018/health-equity-work-agencies.html'],
#  '10.1016/j.puhe.2015.10.027': [1,
#   'https://dacemirror.sci-hub.tw/journal-article/9ee820ea314f598f883ca492ca423add/rosella2016.pdf'],
#  '10.1016/j.epidem.2014.08.008': [1,
#   'https://dabamirror.sci-hub.tw/4670/66d32d1d8b52b6317f3204314af39388/metcalf2015.pdf'],
#  '10.1186/s40504-018-0071-4': [1,
#   'https://cyber.sci-hub.tw/MTAuMTE4Ni9zNDA1MDQtMDE4LTAwNzEtNA==/velasco2018.pdf'],
#  '10.1111/j.1475-6773.2009.01011.x': [1,
#   'https://moscow.sci-hub.tw/963/ae9207f02bb3dcff5753c4cc185858a1/wholey2009.pdf'],
#  '10.1186/1471-2458-12-141': [1,
#   'https://moscow.sci-hub.tw/2063/8cfe732e9765cb3e39a61fc31ca3ba6e/markiewicz2012.pdf'],
#  '10.1145/505282.505283': [1,
#   'https://moscow.sci-hub.tw/1537/ff3ffe9d9f0b1bcc6e02be1b7a8edacd/sebastiani2002.pdf'],
#  '10.3115/1118693.1118704': [1,
#   'https://cyber.sci-hub.tw/MTAuMzExNS8xMTE4NjkzLjExMTg3MDQ=/pang2002.pdf'],
#  '10.1145/330908.331819': [1,
#   'https://dabamirror.sci-hub.tw/4356/2b6310f208a59a835fd6e4916ec24e40/proulx2000.pdf'],
#  '10.1109/2.982917': [1,
#   'https://dacemirror.sci-hub.tw/journal-article/98db5a149d3d12a6a408fd5bcc1e1425/austin2002.pdf'],
#  '10.1109/icse.2005.1553534': [1,
#   'https://cyber.sci-hub.tw/MTAuMTEwOS9pY3NlLjIwMDUuMTU1MzUzNA==/beyond-computer-science.pdf'],
#  '10.2753/mis0742-1222240302': [1,
#   '//sci-hub.tw/downloads/2019-01-28//3f/peffers2007.pdf'],
#  '10.1177/003172171309500111': [1,
#   'https://zero.sci-hub.tw/3768/38d500035faca977d5e20d1deb66c1ac/kafai2013.pdf'],
#  '10.1145/985692.985733': [1,
#   'https://dacemirror.sci-hub.tw/proceedings-article/e1b54fb29f69a939f9b8d38990e1386d/vonahn2004.pdf'],
#  '10.1109/policy.2004.1309145': [1,
#   'https://cyber.sci-hub.tw/MTAuMTEwOS9wb2xpY3kuMjAwNC4xMzA5MTQ1/kephart2004.pdf'],
#  '10.1016/j.ejor.2009.08.003': [1,
#   'https://dacemirror.sci-hub.tw/journal-article/efa14f4ae58e72d4f73fb8c40c2c452e/fethi2010.pdf']}

# %%
upw_db_result = search_db('saa', oa_sampler)
# Out:
# Executing query:
# SELECT doi, is_oa FROM tmp WHERE doi IN ('10.3842/sigma.2012.016','10.1016/j.physrep.2012.01.001','10.1146/annurev-astro-081811-125615','10.1016/j.physletb.2008.07.018','10.1126/science.1202043','10.1140/epjc/s10052-016-4099-4','10.1016/j.aop.2005.04.002','10.1103/physrevlett.94.111601','10.1143/ptps.183.1','10.1143/ptp.113.843','10.1371/journal.pone.0064841','10.1108/jd-03-2016-0030','10.1007/s10900-018-0547-4','10.1016/j.ijinfomgt.2018.07.004','10.1016/j.lisr.2017.03.001','10.1016/j.lisr.2017.03.005','10.1002/asi.23124','10.1145/2998181.2998204','10.1108/jd-06-2017-0095','10.1080/10447318.2017.1365459','10.1177/1464884905056815','10.1177/1464884903004001484','10.1080/1461670x.2011.571825','10.1080/17512780802281065','10.1080/17512786.2012.667269','10.1207/s15506878jobem4604_3','10.1177/1461444809341393','10.1177/0016549205057564','10.1080/14616700500533643','10.1080/14616700118394','10.3390/ijerph14091002','10.1097/phh.0000000000000347','10.11604/pamj.supp.2017.27.1.12570','10.1093/pubmed/fdw130','10.24095/hpcdp.38.7/8.02','10.1016/j.puhe.2015.10.027','10.1016/j.epidem.2014.08.008','10.1186/s40504-018-0071-4','10.1111/j.1475-6773.2009.01011.x','10.1186/1471-2458-12-141','10.1145/505282.505283','10.3115/1118693.1118704','10.1145/330908.331819','10.1109/2.982917','10.1109/icse.2005.1553534','10.2753/mis0742-1222240302','10.1177/003172171309500111','10.1145/985692.985733','10.1109/policy.2004.1309145','10.1016/j.ejor.2009.08.003')
#
# # of article found in upw db:42

# %%
upw_add_result = search_missing(oa_sampler, upw_db_result)
upw_df = pd.DataFrame(list({**upw_db_result, **upw_add_result}.items()), columns=['doi','upw_oa'])
# Out:
# Missing doi:
# ['10.1016/j.physletb.2008.07.018', '10.1177/0016549205057564', '10.2753/mis0742-1222240302', '10.1145/330908.331819', '10.1080/17512780802281065', '10.1207/s15506878jobem4604_3', '10.1103/physrevlett.94.111601', '10.1097/phh.0000000000000347']
# # total missing doi: 8
# # valid missing doi: 8
# # of brocken missing doi: 0

# %%
oa_result = validate(oa_sampler, upw_df)
oa_result.head()
# Out:
# ******************OA Result Summary********************
#
# # of articles Google Scholar found OA: 46
# # of articles Google Scholar found NOT OA: 4
#
# # of articles Unpaywall found OA: 25
# # of articles Unpaywall found NOT OA: 25
#
# ******************End OA Result Summary****************
#                                    doi  is_oa  upw_oa  check
# 0               10.3842/sigma.2012.016      1       1      1
# 1        10.1016/j.physrep.2012.01.001      1       1      1
# 2  10.1146/annurev-astro-081811-125615      1       1      1
# 3       10.1016/j.physletb.2008.07.018      1       0      0
# 4              10.1126/science.1202043      1       1      1

# %%
oa_diff = evaluation(oa_result)
# Out:
# Within those 25 articles Unpaywall found OA:
# 25 is (are) acutally OA.
#
# Within those 25 articles Unpaywall NOT found OA:
# 4 is (are) acutally NOT OA.
#
# Precision = 25 / 25 = 100.0%
# Racall = 25 / 46 = 54.347826086956516%

# %%
oa_diff
# Out:
#                                doi  is_oa  upw_oa  check
# 3   10.1016/j.physletb.2008.07.018      1       0      0
# 11         10.1108/jd-03-2016-0030      1       0      0
# 12       10.1007/s10900-018-0547-4      1       0      0
# 17         10.1145/2998181.2998204      1       0      0
# 18         10.1108/jd-06-2017-0095      1       0      0
# 19   10.1080/10447318.2017.1365459      1       0      0
# 20        10.1177/1464884905056815      1       0      0
# 21     10.1177/1464884903004001484      1       0      0
# 24    10.1080/17512786.2012.667269      1       0      0
# 25    10.1207/s15506878jobem4604_3      1       0      0
# 27        10.1177/0016549205057564      1       0      0
# 28       10.1080/14616700500533643      1       0      0
# 29          10.1080/14616700118394      1       0      0
# 33           10.1093/pubmed/fdw130      1       0      0
# 34        10.24095/hpcdp.38.7/8.02      1       0      0
# 42           10.1145/330908.331819      1       0      0
# 43                10.1109/2.982917      1       0      0
# 44       10.1109/icse.2005.1553534      1       0      0
# 46      10.1177/003172171309500111      1       0      0
# 48     10.1109/policy.2004.1309145      1       0      0
# 49      10.1016/j.ejor.2009.08.003      1       0      0

# %%
# search Unpaywall Database
def search_db(db_name, search_df): 
    cnx = mysql.connector.connect(user='scott', password='tiger',
                                  host='127.0.0.1',
                                  database=db_name,
                                  use_pure=False)
    cursor = cnx.cursor()
    search_doi ='\',\''.join(search_df.doi)
    query = ("SELECT doi, is_oa FROM tmp WHERE doi IN (\'{}\')").format(search_doi)
    print ("Executing query:\n" + query + "\n")
    cursor.execute(query)
    result = {doi: 0 if is_oa == 'False' else 1 for (doi, is_oa) in cursor}
    print("# of article found in upw db:{}".format(len(result)))
    return result
# check missing and brocken doi based on the result returned by search_db
def call_crossref_api(list_of_doi):
    crossref_base = 'https://api.crossref.org/works/{}/agency'
    resp, err = [], []
    for doi in list_of_doi:
        try:
            with urllib.request.urlopen(crossref_base.format(doi)) as url:
                resp.append(json.loads(url.read().decode()))
        except (UnicodeEncodeError, urllib.error.HTTPError) as e:
            err.append({doi : 'Code: {c}, Message, {m}'.format(c = type(e).__name__, m = str(e))})
            continue
    return resp, err
# query valid missing doi with unpaywall API
def call_upw_api(list_of_doi):
    upw_base = 'https://api.unpaywall.org/v2/{}?email=hanlin.zhang@unc.edu'
    resp = []
    for doi in list_of_doi:
        with urllib.request.urlopen(upw_base.format(doi)) as url:
            resp.append(json.loads(url.read().decode()))
    return resp
# Add missing query result by calling `call_crossref_apiand` and `call_upw_api`
def search_missing(input_df, upw_db_result):
    diff = list(set(input_df.doi)-set(upw_db_result))
    print('Missing doi:\n{}'.format(diff))
    # Searching missing doi with Crossref
    crsref_resp, crsref_err = call_crossref_api(diff)
    vaild_doi = [json['message']['DOI'] for json in crsref_resp]
    print("# total missing doi: {}".format(len(diff)))
    print("# valid missing doi: {}".format(len(vaild_doi)))
    print("# of brocken missing doi: {}".format(len(crsref_err)))
    # Searching valid doi with Unpaywall API
    upw_resp = call_upw_api(vaild_doi)
    add_result = {json['doi']: 0 if json['is_oa'] != True else 1 for json in upw_resp}
    return add_result
# validate Unpaywall result with Google Scholar
def validate(vaild_df, query_df):
    vaild_df.is_oa = vaild_df.is_oa.astype(bool) *1
    query_df.upw_oa = query_df.upw_oa.astype(bool)*1
    tmp = pd.merge(vaild_df[['doi', 'is_oa']], query_df, on='doi', how='left')
    tmp['check'] = tmp.apply(lambda x : 0 if x['is_oa'] != x['upw_oa'] else 1, axis=1)
    print("*"*18 + "OA Result Summary" + "*"*20 +"\n")
    print("# of articles Google Scholar found OA: {}".format(tmp.is_oa.sum()))
    print("# of articles Google Scholar found NOT OA: {} \n".format(len(vaild_df) - tmp.is_oa.sum()))
    print("# of articles Unpaywall found OA: {}".format(tmp.upw_oa.sum()))
    print("# of articles Unpaywall found NOT OA: {} \n".format(len(vaild_df) - tmp.upw_oa.sum()))
    print("*"*18 + "End OA Result Summary" + "*"*16)
    return tmp
# calculate Precision and Racall
def evaluation(result_df):
    # masks for T&F
    t_mask = result_df.check == 1
    f_mask = result_df.check == 0
    # Get upw OA counts
    upw_oa_count = result_df.upw_oa.sum()
    upw_n_oa_count = len(result_df)- upw_oa_count
    # Get Google Scholar OA counts
    gs_oa_count= result_df.is_oa.sum()
    gs_n_oa_count = len(result_df)- gs_oa_count
    # Set Google Scholar as bench mark, find True-Positive for Unpaywall:
    TP = result_df[t_mask].is_oa.sum()
    print("Within those {} articles Unpaywall found OA:\n" \
      "{} is (are) acutally OA. \n".format(upw_oa_count, TP))
    # Set Google Scholar as bench mark, find True-Negative for Unpaywall:
    TN = len(result_df[t_mask]) - result_df[t_mask].upw_oa.sum()
    print("Within those {} articles Unpaywall NOT found OA:\n" \
      "{} is (are) acutally NOT OA. \n".format(upw_n_oa_count, TN))
    print('Precision = {} / {} = {}%'.format(TP, upw_oa_count, TP/upw_oa_count*100))
    print('Racall = {} / {} = {}%'.format(TP, gs_oa_count, TP/gs_oa_count*100))
    
    return result_df[f_mask]
